# %%
import pandas as pd

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/arteweyl/material_turma58865/main/datasets/Cancer_Data.csv', encoding='latin1')
df1
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df2 = pd.read_excel('https://raw.githubusercontent.com/arteweyl/material_turma58865/main/datasets/fastfood.xlsx')
df2.to_excel('../datasets/fastfood.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 2
#       1 df2 = pd.read_excel('https://raw.githubusercontent.com/arteweyl/material_turma58865/main/datasets/fastfood.xlsx')
# ----> 2 df2.to_excel('../datasets/fastfood.xlsx', index=False)
#
# File c:\Users\eduar\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...
