# %%
import pandas as pd
import requests

# %%
import requests

url = "https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=en-US&page=1&sort_by=popularity.desc"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIwNzhkMzdlMGQ0ZTExYjY5ZWM1ZDQ0NDFjNGEyZDJjMiIsIm5iZiI6MTcyOTk3NDM5Ny40NjU4MSwic3ViIjoiNjY5YTg2MDFmZWIxNmQwYzZiZjgxNzkxIiwic2NvcGVzIjpbImFwaV9yZWFkIl0sInZlcnNpb24iOjF9.J3vSm-P_xisyFzUzIIIuz6hRVjP0cL5InKLPfvqCEjA"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"page":1,"results":[{"adult":false,"backdrop_path":"/v9acaWVVFdZT5yAU7J2QjwfhXyD.jpg","genre_ids":[16,878,10751],"id":1184918,"original_language":"en","original_title":"The Wild Robot","overview":"After a shipwreck, an intelligent robot called Roz is stranded on an uninhabited island. To survive the harsh environment, Roz bonds with the island's animals and cares for an orphaned baby goose.","popularity":7140.064,"poster_path":"/wTnV3PCVW5O92JMrFvvrRcV39RU.jpg","release_date":"2024-09-12","title":"The Wild Robot","video":false,"vote_average":8.6,"vote_count":1754},{"adult":false,"backdrop_path":"/3V4kLQg0kSqPLctI5ziYWabAZYF.jpg","genre_ids":[878,28,12],"id":912649,"original_language":"en","original_title":"Venom: The Last Dance","overview":"Eddie and Venom are on the run. Hunted by both of their worlds and with the net closing in, the duo are forced into a devastating decision that will bring the curtains down on Venom and Eddie's last dance.","popularity":5868.656,"poster_path":"/6
# ...

# %%
#Verificando se tudo está ok e transformando as infos em JSON

if response.status_code == 200:
    data_json = response.json()
    print(data_json)
    
else:
    print('Erro')
# Out:
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/v9acaWVVFdZT5yAU7J2QjwfhXyD.jpg', 'genre_ids': [16, 878, 10751], 'id': 1184918, 'original_language': 'en', 'original_title': 'The Wild Robot', 'overview': "After a shipwreck, an intelligent robot called Roz is stranded on an uninhabited island. To survive the harsh environment, Roz bonds with the island's animals and cares for an orphaned baby goose.", 'popularity': 7140.064, 'poster_path': '/wTnV3PCVW5O92JMrFvvrRcV39RU.jpg', 'release_date': '2024-09-12', 'title': 'The Wild Robot', 'video': False, 'vote_average': 8.6, 'vote_count': 1754}, {'adult': False, 'backdrop_path': '/3V4kLQg0kSqPLctI5ziYWabAZYF.jpg', 'genre_ids': [878, 28, 12], 'id': 912649, 'original_language': 'en', 'original_title': 'Venom: The Last Dance', 'overview': "Eddie and Venom are on the run. Hunted by both of their worlds and with the net closing in, the duo are forced into a devastating decision that will bring the curtains down on Venom and Eddie's last
# ...

# %%
#Fazer virar um data frame
df = pd.DataFrame(data_json)
df.head()
# Out:
#    page                                            results  total_pages  \
# 0     1  {'adult': False, 'backdrop_path': '/v9acaWVVFd...        46785
# 1     1  {'adult': False, 'backdrop_path': '/3V4kLQg0kS...        46785
# 2     1  {'adult': False, 'backdrop_path': '/xlkclSE4aq...        46785
# 3     1  {'adult': False, 'backdrop_path': '/9SSEUrSqhl...        46785
# 4     1  {'adult': False, 'backdrop_path': '/9oYdz5gDoI...        46785
#
#    total_results
# 0         935693
# 1         935693
# 2         935693
# 3         935693
# 4         935693

# %%
df = pd.DataFrame(data_json)
chaves = df.keys()

chaves
# Out:
# Index(['page', 'results', 'total_pages', 'total_results'], dtype='object')

# %%
data_json
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/v9acaWVVFdZT5yAU7J2QjwfhXyD.jpg',
#    'genre_ids': [16, 878, 10751],
#    'id': 1184918,
#    'original_language': 'en',
#    'original_title': 'The Wild Robot',
#    'overview': "After a shipwreck, an intelligent robot called Roz is stranded on an uninhabited island. To survive the harsh environment, Roz bonds with the island's animals and cares for an orphaned baby goose.",
#    'popularity': 7140.064,
#    'poster_path': '/wTnV3PCVW5O92JMrFvvrRcV39RU.jpg',
#    'release_date': '2024-09-12',
#    'title': 'The Wild Robot',
#    'video': False,
#    'vote_average': 8.6,
#    'vote_count': 1754},
#   {'adult': False,
#    'backdrop_path': '/3V4kLQg0kSqPLctI5ziYWabAZYF.jpg',
#    'genre_ids': [878, 28, 12],
#    'id': 912649,
#    'original_language': 'en',
#    'original_title': 'Venom: The Last Dance',
# ...
